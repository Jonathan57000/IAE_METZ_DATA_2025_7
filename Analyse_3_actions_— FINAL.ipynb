# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonathan57000/IAE_METZ_DATA_2025_7/blob/main/Analyse_3_actions_%E2%80%94%C2%A0FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Collecte des données financières

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#comparaison de 3 actifs
Apple='AAPL'
asml = 'ASML'
TSMC='2330.TW' #Taiwan Semiconductor Manufacturing Company
Nasdaq="NQ=F"

# %%
#time frame
start_date = "2015-01-01"
end_date = "2025-01-01"

# %%
#téléchargement des données historiquess avec yahoo finance
apple_data = yf.download(Apple, start=start_date, end=end_date)
asml_data = yf.download(asml, start=start_date, end=end_date)
tsmc_data = yf.download(TSMC, start=start_date, end=end_date)

nasdaq_data=yf.download ("NQ=F", start=start_date, end=end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# #Mise en forme des données

# %%
apple_data.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-01-02  24.320435  24.789804  23.879983  24.778681  212818400
# 2015-01-05  23.635286  24.169166  23.448429  24.089084  257142000
# 2015-01-06  23.637510  23.897776  23.274916  23.699796  263188400
# 2015-01-07  23.968962  24.069063  23.735389  23.846614  160423600
# 2015-01-08  24.889898  24.947736  24.180283  24.298183  237458000

# %%
# Calcul des rendements journaliers
apple_daily = apple_data.pct_change().dropna()

# Calcul de la rentabilité annualisée
apple_mean_daily_return = apple_daily["Close"].mean()  # Rendement moyen journalier
apple_annualized_return = (1 + apple_mean_daily_return) ** 252 - 1  # Annualisation

print(apple_annualized_return)
# Out:
# Ticker
# AAPL    0.315203
# dtype: float64

# %%
# Calcul des rendements journaliers
asml_daily = asml_data.pct_change().dropna()

# Calcul de la rentabilité annualisée
asml_mean_daily_return = asml_daily["Close"].mean()  # Rendement moyen journalier
asml_annualized_return = (1 + asml_mean_daily_return) ** 252 - 1  # Annualisation

print(asml_annualized_return)
# Out:
# Ticker
# ASML    0.302489
# dtype: float64

# %%
# Calcul des rendements journaliers
tsmc_daily = tsmc_data.pct_change().dropna()

# Calcul de la rentabilité annualisée
tsmc_mean_daily_return = tsmc_daily["Close"].mean()  # Rendement moyen journalier
tsmc_annualized_return = (1 + tsmc_mean_daily_return) ** 252 - 1  # Annualisation

print(tsmc_annualized_return)
# Out:
# Ticker
# 2330.TW    0.317474
# dtype: float64

# %%
#calcul nasdaq 100 rendements
nasdaq_daily = nasdaq_data.pct_change().dropna()

# %%
#Définir une fenêtre de lissage (exemple : 30 jours)
window = 30
apple_smooth = apple_daily["Close"].resample("M").mean()
asml_smooth = asml_daily["Close"].resample("M").mean()
tsmc_smooth = tsmc_daily["Close"].resample("M").mean()
nasdaq_smooth = nasdaq_daily["Close"].resample("M").mean()

#Tracer les courbes lissées
plt.figure(figsize=(30, 10))  # Agrandir le graphique
plt.plot(apple_smooth, label="Apple", color="mediumpurple", linewidth=2)
plt.plot(asml_smooth, label="ASML", color="deeppink", linewidth=2)
plt.plot(tsmc_smooth, label="TSMC", color="skyblue", linewidth=2)
plt.plot(nasdaq_smooth, label="Nasdaq", color="green", linewidth=5)

plt.title("Évolution des rentabilités mensualisées des actifs (2015–2025)", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Rentabilité", fontsize=12)
plt.legend()

# Améliorations visuelles
plt.xticks(rotation=45)  # Rotation des dates
plt.locator_params(axis="x", nbins=10)  # Moins de ticks pour lisibilité
plt.grid(True, linestyle="--", alpha=0.5)  # Ajouter une grille légère

plt.show()
# Out:
# <ipython-input-43-f0b37204f970>:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   apple_smooth = apple_daily["Close"].resample("M").mean()
# <ipython-input-43-f0b37204f970>:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   asml_smooth = asml_daily["Close"].resample("M").mean()
# <ipython-input-43-f0b37204f970>:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   tsmc_smooth = tsmc_daily["Close"].resample("M").mean()
# <ipython-input-43-f0b37204f970>:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   nasdaq_smooth = nasdaq_daily["Close"].resample("M").mean()
# <ipython-input-43-f0b37204f970>:23: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis="x", nbins=10)  # Moins de ticks pour lisibilité

# %% [markdown]
# #Calcul de la volatilité et du ratio de Sharpe

# %%
# Assume risk-free rate is 0.03 (3%)
risk_free_rate = 0.03


# Calculate annualized standard deviation for APPLE
apple_sd = apple_daily["Close"].std() * np.sqrt(252)
print(apple_sd)

# Calculate Sharpe Ratio
apple_sharpe_ratio = (apple_annualized_return - risk_free_rate) / apple_sd

print(apple_sharpe_ratio)
# Out:
# Ticker
# AAPL    0.284618
# dtype: float64
# Ticker
# AAPL    1.002056
# dtype: float64

# %%
# Calculate annualized standard deviation for APPLE
asml_sd = asml_daily["Close"].std() * np.sqrt(252)
print(asml_sd)

# Calculate Sharpe Ratio
asml_sharpe_ratio = (asml_annualized_return - risk_free_rate) / asml_sd

print(asml_sharpe_ratio)
# Out:
# Ticker
# ASML    0.366866
# dtype: float64
# Ticker
# ASML    0.742747
# dtype: float64

# %%
# Calculate annualized standard deviation for APPLE
tsmc_sd = tsmc_daily["Close"].std() * np.sqrt(252)
print(tsmc_sd)

# Calculate Sharpe Ratio
tsmc_sharpe_ratio = (tsmc_annualized_return - risk_free_rate) / tsmc_sd

print(tsmc_sharpe_ratio)
# Out:
# Ticker
# 2330.TW    0.261385
# dtype: float64
# Ticker
# 2330.TW    1.099809
# dtype: float64

# %% [markdown]
# #Graphique des prix ajsustés

# %%
#tracer l'évolution des prix ajustés
plt.figure(figsize=(12, 6))
plt.plot(apple_data ["Close"], label="Apple", color="mediumpurple")
plt.plot(asml_data ["Close"], label="ASML", color="deeppink")
plt.plot(tsmc_data ["Close"], label="TSMC", color="skyblue")


#ajouter des titres et labels
plt.title("Évolution des prix ajustés des actifs (2015-2025)", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Prix ajusté ($)", fontsize=12)
plt.legend()
plt.show()

# %%
#calcul des rendements quotidiens pour chacun des actifs
apple_returns = apple_data.pct_change().dropna()
asml_returns = asml_data.pct_change().dropna()
tsmc_returns = tsmc_data.pct_change().dropna()
nasdaq_returns = nasdaq_data.pct_change().dropna()
print(apple_returns)
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL
# Date
# 2015-01-05 -0.028172 -0.025036 -0.018072 -0.027830  0.208270
# 2015-01-06  0.000094 -0.011229 -0.007400 -0.016160  0.023514
# 2015-01-07  0.014022  0.007167  0.019784  0.006195 -0.390461
# 2015-01-08  0.038422  0.036507  0.018744  0.018937  0.480194
# 2015-01-09  0.001072  0.009808  0.013891  0.031493 -0.095427
# ...              ...       ...       ...       ...       ...
# 2024-12-24  0.011478  0.010014  0.007260  0.002826 -0.431342
# 2024-12-26  0.003176  0.007320  0.009166  0.010568  0.172260
# 2024-12-27 -0.013242 -0.005382 -0.017739 -0.001394  0.555059
# 2024-12-30 -0.013263 -0.020101 -0.009128 -0.021720 -0.160495
# 2024-12-31 -0.007058 -0.000868 -0.005264  0.000833  0.110334
#
# [2515 rows x 5 columns]

# %%
#calcul de la rentabilité cumulée des actifs sur une période
apple_cumulative_return=(1+apple_returns).cumprod()-1
asml_return=(1+asml_returns).cumprod()-1
tsmc_cumulative_return=(1+tsmc_returns).cumprod()-1
print(apple_cumulative_return)
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL
# Date
# 2015-01-05 -0.028172 -0.025036 -0.018072 -0.027830  0.208270
# 2015-01-06 -0.028080 -0.035983 -0.025338 -0.043541  0.236681
# 2015-01-07 -0.014452 -0.029074 -0.006055 -0.037616 -0.246195
# 2015-01-08  0.023415  0.006371  0.012576 -0.019391  0.115778
# 2015-01-09  0.024513  0.016242  0.026642  0.011491  0.009302
# ...              ...       ...       ...       ...       ...
# 2024-12-24  9.604928  9.404537  9.678803  9.299557 -0.890824
# 2024-12-26  9.638606  9.480694  9.776685  9.408401 -0.872017
# 2024-12-27  9.497728  9.424282  9.585522  9.393889 -0.800979
# 2024-12-30  9.358493  9.214749  9.488895  9.168136 -0.832921
# 2024-12-31  9.285383  9.205884  9.433679  9.176602 -0.814486
#
# [2515 rows x 5 columns]
# /usr/local/lib/python3.11/dist-packages/numpy/core/fromnumeric.py:59: RuntimeWarning: invalid value encountered in accumulate
#   return bound(*args, **kwds)

# %% [markdown]
# #Mise en portefeuille

# %%
ticker=["AAPL",'NOVO-B.CO','2330.TW']
portefeuille = yf.download(ticker, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
#calcul de la rentabilité du portefeuille
portefeuille_return= portefeuille.pct_change().dropna()
print (portefeuille_return)
# Out:
# Price          Close                          High                      \
# Ticker       2330.TW      AAPL NOVO-B.CO   2330.TW      AAPL NOVO-B.CO
# Date
# 2015-01-06 -0.043011  0.000094 -0.006775 -0.021352 -0.011229 -0.004120
# 2015-01-07  0.003745  0.014022  0.002653 -0.018182  0.007168  0.001880
# 2015-01-08  0.029851  0.038422  0.019652  0.022222  0.036506  0.016892
# 2015-01-09 -0.028985  0.001073  0.003706 -0.018116  0.009809  0.006275
# 2015-01-12 -0.014925 -0.024641  0.013663 -0.014760 -0.005475  0.007704
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-25  0.004630  0.000000  0.000000 -0.004566  0.000000  0.000000
# 2024-12-26  0.000000  0.003176  0.000000  0.000000  0.007320  0.000000
# 2024-12-27  0.004608 -0.013242  0.021362  0.004587 -0.005382 -0.005086
# 2024-12-30  0.000000 -0.013263 -0.018399  0.000000 -0.020101 -0.012392
# 2024-12-31 -0.013761 -0.007058  0.000000 -0.009132 -0.000868  0.000000
#
# Price            Low                          Open                      \
# Ticker       2330.TW      AAPL NOVO-B.CO   2330.TW      AAPL NOVO-B.CO
# Date
# 2015-01-06 -0.032727 -0.007400 -0.009470 -0.021352 -0.016160  0.001885
# 2015-01-07  0.003760  0.019784  0.009178 -0.029091  0.006195 -0.006398
# 2015-01-08  0.018726  0.018744  0.006821  0.022472  0.018936  0.010227
# 2015-01-09 -0.022059  0.013892  0.014678 -0.010989  0.031493  0.012373
# 2015-01-12 -0.007519 -0.012794  0.005564 -0.018519 -0.000621  0.007407
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-25  0.000000  0.000000  0.000000 -0.004566  0.000000  0.000000
# 2024-12-26  0.004630  0.009166  0.000000 -0.004587  0.010568  0.000000
# 2024-12-27 -0.004608 -0.017739  0.024869 -0.004608 -0.001394  0.024715
# 2024-12-30  0.004630 -0.009128 -0.017401  0.009259 -0.021720  0.009045
# 2024-12-31 -0.009217 -0.005264  0.000000 -0.009174  0.000833  0.000000
#
# Price         Volume
# Ticker       2330.TW      AAPL NOVO-B.CO
# Date
# 2015-01-06  1.083817  0.023514 -0.149604
# 2015-01-07 -0.345548 -0.390461  0.294461
# 2015-01-08 -0.027733  0.480194  0.248041
# 2015-01-09  0.448730 -0.095427 -0.379178
# 2015-01-12 -0.507164 -0.075395 -0.142499
# ...              ...       ...       ...
# 2024-12-25 -0.414947  0.000000  0.000000
# 2024-12-26 -0.071486  0.172260  0.000000
# 2024-12-27  0.735552  0.555059 -0.561327
# 2024-12-30 -0.039832 -0.160495  0.049646
# 2024-12-31  0.185483  0.110334  0.000000
#
# [2597 rows x 15 columns]
# <ipython-input-33-1e2eee6ef6a4>:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   portefeuille_return= portefeuille.pct_change().dropna()

# %% [markdown]
# #Information sur les actifs

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
apple=yf.Ticker("AAPL")
asml=yf.Ticker("ASML")
tsmc=yf.Ticker("2330.TW")

# %%
apple.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 150000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 63,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2023,
#    'totalPay': 16239562,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'age': 60,
#    'title': 'Chief Operating Officer',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 4637585,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 60,
#    'title': 'Senior VP, General Counsel & Secretary',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 4618064,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 57,
#    'title': 'Chief People Officer & Senior VP of Retail',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 4613369,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevan  Parekh',
#    'age': 52,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Senior Director of Corporate Accounting',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kristin Huguet Quayle',
#    'title': 'Vice President of Worldwide Communications',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adrian  Perica',
#    'age': 50,
#    'title': 'Vice President of Corporate Development',
#    'yearBorn': 1974,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 7,
#  'boardRisk': 1,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1740787200,
#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://investor.apple.com/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 235.33,
#  'open': 235.105,
#  'dayLow': 234.76,
#  'dayHigh': 241.37,
#  'regularMarketPreviousClose': 235.33,
#  'regularMarketOpen': 235.105,
#  'regularMarketDayLow': 234.76,
#  'regularMarketDayHigh': 241.37,
#  'dividendRate': 1.0,
#  'dividendYield': 0.42,
#  'exDividendDate': 1739145600,
#  'payoutRatio': 0.1571,
#  'fiveYearAvgDividendYield': 0.59,
#  'beta': 1.178,
#  'trailingPE': 37.88748,
#  'forwardPE': 28.768953,
#  'volume': 46273565,
#  'regularMarketVolume': 46273565,
#  'averageVolume': 51307969,
#  'averageVolume10days': 48138610,
#  'averageDailyVolume10Day': 48138610,
#  'bid': 238.94,
#  'ask': 239.06,
#  'bidSize': 1,
#  'askSize': 1,
#  'marketCap': 3591333740544,
#  'fiftyTwoWeekLow': 164.08,
#  'fiftyTwoWeekHigh': 260.1,
#  'priceToSalesTrailing12Months': 9.074524,
#  'fiftyDayAverage': 238.766,
#  'twoHundredDayAverage': 227.0861,
#  'trailingAnnualDividendRate': 0.99,
#  'trailingAnnualDividendYield': 0.0042068586,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 3634351046656,
#  'profitMargins': 0.24295,
#  'floatShares': 14998187904,
#  'sharesOutstanding': 15022100480,
#  'sharesShort': 127893856,
#  'sharesShortPriorMonth': 135189465,
#  'sharesShortPreviousMonthDate': 1736899200,
#  'dateShortInterest': 1739491200,
#  'sharesPercentSharesOut': 0.0085,
#  'heldPercentInsiders': 0.02268,
#  'heldPercentInstitutions': 0.62777,
#  'shortRatio': 2.22,
#  'shortPercentOfFloat': 0.0085,
#  'impliedSharesOutstanding': 15262499840,
#  'bookValue': 4.438,
#  'priceToBook': 53.86886,
#  'lastFiscalYearEnd': 1727481600,
#  'nextFiscalYearEnd': 1759017600,
#  'mostRecentQuarter': 1735344000,
#  'earningsQuarterlyGrowth': 0.071,
#  'netIncomeToCommon': 96150003712,
#  'trailingEps': 6.31,
#  'forwardEps': 8.31,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 9.183,
#  'enterpriseToEbitda': 26.46,
#  '52WeekChange': 0.38390744,
#  'SandP52WeekChange': 0.12744582,
#  'lastDividendValue': 0.25,
#  'lastDividendDate': 1739145600,
#  'quoteType': 'EQUITY',
#  'currentPrice': 239.07,
#  'targetHighPrice': 325.0,
#  'targetLowPrice': 197.0,
#  'targetMeanPrice': 252.92384,
#  'targetMedianPrice': 260.0,
#  'recommendationMean': 2.04444,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 39,
#  'totalCash': 53774999552,
#  'totalCashPerShare': 3.58,
#  'ebitda': 137352003584,
#  'totalDebt': 96798998528,
#  'quickRatio': 0.783,
#  'currentRatio': 0.923,
#  'totalRevenue': 395760009216,
#  'debtToEquity': 145.0,
#  'revenuePerShare': 25.974,
#  'returnOnAssets': 0.22518998,
#  'returnOnEquity': 1.3652,
#  'grossProfits': 184102993920,
#  'freeCashflow': 93833871360,
#  'operatingCashflow': 108293996544,
#  'earningsGrowth': 0.101,
#  'revenueGrowth': 0.04,
#  'grossMargins': 0.46519002,
#  'ebitdaMargins': 0.34706002,
#  'operatingMargins': 0.34459,
#  'financialCurrency': 'USD',
#  'symbol': 'AAPL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'corporateActions': [],
#  'postMarketTime': 1741395574,
#  'regularMarketTime': 1741381202,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_24937',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': 1.5892599,
#  'regularMarketPrice': 239.07,
#  'marketState': 'CLOSED',
#  'hasPrePostMarketData': True,
#  'postMarketChangePercent': -0.154771,
#  'postMarketPrice': 238.7,
#  'postMarketChange': -0.37001,
#  'regularMarketChange': 3.7400055,
#  'regularMarketDayRange': '234.76 - 241.37',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 51307969,
#  'firstTradeDateMilliseconds': 345479400000,
#  'fiftyTwoWeekLowChange': 74.990005,
#  'fiftyTwoWeekLowChangePercent': 0.4570332,
#  'fiftyTwoWeekRange': '164.08 - 260.1',
#  'fiftyTwoWeekHighChange': -21.029999,
#  'fiftyTwoWeekHighChangePercent': -0.080853514,
#  'fiftyTwoWeekChangePercent': 38.390743,
#  'dividendDate': 1739404800,
#  'earningsTimestamp': 1738272600,
#  'earningsTimestampStart': 1746010740,
#  'earningsTimestampEnd': 1746446400,
#  'earningsCallTimestampStart': 1738274400,
#  'earningsCallTimestampEnd': 1738274400,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 6.31,
#  'epsForward': 8.31,
#  'epsCurrentYear': 7.33465,
#  'priceEpsCurrentYear': 32.594604,
#  'fiftyDayAverageChange': 0.30400085,
#  'fiftyDayAverageChangePercent': 0.0012732167,
#  'twoHundredDayAverageChange': 11.983902,
#  'twoHundredDayAverageChangePercent': 0.052772503,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '2.0 - Buy',
#  'cryptoTradeable': False,
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'displayName': 'Apple',
#  'trailingPegRatio': 2.2142}

# %%
asml.info
# Out:
# {'address1': 'De Run 6501',
#  'city': 'Veldhoven',
#  'zip': '5504 DR',
#  'country': 'Netherlands',
#  'phone': '31 40 268 3938',
#  'website': 'https://www.asml.com',
#  'industry': 'Semiconductor Equipment & Materials',
#  'industryKey': 'semiconductor-equipment-materials',
#  'industryDisp': 'Semiconductor Equipment & Materials',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'ASML Holding N.V. provides lithography solutions for the development, production, marketing, sales, upgrading, and servicing of advanced semiconductor equipment systems. It offers lithography, metrology, and inspection systems. The company also provides extreme ultraviolet lithography systems; and deep ultraviolet lithography systems comprising immersion and dry lithography systems solutions to manufacture various range of semiconductor nodes and technologies. In addition, it offers metrology and inspection systems, including YieldStar optical metrology systems to assess the quality of patterns on the wafers; and HMI electron beam solutions to identify and analyze individual chip defects. Further, the company provides computational lithography solutions, and lithography systems and control software solutions; and refurbishes and upgrades lithography systems, as well as offers customer support and related services. Additionally, it offers hardware, software, and services to chipmakers to produce the patterns of integrated circuits. The company operates in Japan, South Korea, Singapore, Taiwan, China, rest of Asia, the Netherlands, rest of Europe, the Middle East, Africa, and the United States. The company was formerly known as ASM Lithography Holding N.V. and changed its name to ASML Holding N.V. in 2001. ASML Holding N.V. was founded in 1984 and is headquartered in Veldhoven, the Netherlands.',
#  'fullTimeEmployees': 42786,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Christophe D. Fouquet',
#    'age': 51,
#    'title': 'President, CEO and Chair of the Board of Management',
#    'yearBorn': 1973,
#    'fiscalYear': 2024,
#    'totalPay': 2908124,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Roger J. M. Dassen Ph.D.',
#    'age': 59,
#    'title': 'Executive VP, CFO & Member of the Management Board',
#    'yearBorn': 1965,
#    'fiscalYear': 2024,
#    'totalPay': 2136956,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frederic J. M. Schneider-Maunoury',
#    'age': 63,
#    'title': 'Executive VP, COO & Member of the Management Board',
#    'yearBorn': 1961,
#    'fiscalYear': 2024,
#    'totalPay': 2157535,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James P. Koonmen',
#    'age': 57,
#    'title': 'Executive VP, Chief Customer Officer & Member of Management Board',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 1806966,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Wayne R. Allan',
#    'age': 57,
#    'title': 'Executive VP, Chief Strategic Sourcing & Procurement Officer and Member of Management Board',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 2248516,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Skip  Miller',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ron  Kool',
#    'title': 'Head of Business Performance Improvement',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Rob Van Vliet',
#    'title': 'Investor Relations Manager',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Peter  Convertito',
#    'title': 'Director Investor Relations- North America',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://www.asml.com/asml/show.do?ctx=32918',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 732.22,
#  'open': 698.28,
#  'dayLow': 681.88,
#  'dayHigh': 699.0,
#  'regularMarketPreviousClose': 732.22,
#  'regularMarketOpen': 698.28,
#  'regularMarketDayLow': 681.88,
#  'regularMarketDayHigh': 699.0,
#  'dividendRate': 7.68,
#  'dividendYield': 1.05,
#  'exDividendDate': 1745798400,
#  'payoutRatio': 0.3254,
#  'fiveYearAvgDividendYield': 0.81,
#  'beta': 1.113,
#  'trailingPE': 33.274616,
#  'forwardPE': 25.822098,
#  'volume': 1173566,
#  'regularMarketVolume': 1173566,
#  'averageVolume': 1686401,
#  'averageVolume10days': 1761740,
#  'averageDailyVolume10Day': 1761740,
#  'bid': 688.68,
#  'ask': 690.15,
#  'bidSize': 1,
#  'askSize': 1,
#  'marketCap': 271091744768,
#  'fiftyTwoWeekLow': 645.45,
#  'fiftyTwoWeekHigh': 1110.09,
#  'priceToSalesTrailing12Months': 9.591788,
#  'fiftyDayAverage': 731.7656,
#  'twoHundredDayAverage': 818.0852,
#  'trailingAnnualDividendRate': 6.4,
#  'trailingAnnualDividendYield': 0.008740543,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 280284102656,
#  'profitMargins': 0.26790002,
#  'floatShares': 393063481,
#  'sharesOutstanding': 393200000,
#  'sharesShort': 1426294,
#  'sharesShortPriorMonth': 1476036,
#  'sharesShortPreviousMonthDate': 1736899200,
#  'dateShortInterest': 1739491200,
#  'sharesPercentSharesOut': 0.0036000002,
#  'heldPercentInsiders': 0.00078,
#  'heldPercentInstitutions': 0.18659,
#  'shortRatio': 0.73,
#  'shortPercentOfFloat': 0.004,
#  'impliedSharesOutstanding': 399065984,
#  'bookValue': 46.981,
#  'priceToBook': 14.675082,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1735603200,
#  'earningsQuarterlyGrowth': 0.315,
#  'netIncomeToCommon': 7571599872,
#  'trailingEps': 20.72,
#  'forwardEps': 26.7,
#  'lastSplitFactor': '8:9',
#  'lastSplitDate': 1191196800,
#  'enterpriseToRevenue': 9.917,
#  'enterpriseToEbitda': 28.422,
#  '52WeekChange': -0.23938626,
#  'SandP52WeekChange': 0.12744582,
#  'lastDividendValue': 1.641,
#  'lastDividendDate': 1730160000,
#  'quoteType': 'EQUITY',
#  'currentPrice': 689.45,
#  'targetHighPrice': 1143.8474,
#  'targetLowPrice': 716.02576,
#  'targetMeanPrice': 959.3625,
#  'targetMedianPrice': 928.91626,
#  'recommendationMean': 1.76923,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 12,
#  'totalCash': 12750600192,
#  'totalCashPerShare': 32.421,
#  'ebitda': 9861399552,
#  'totalDebt': 5064500224,
#  'quickRatio': 0.91,
#  'currentRatio': 1.533,
#  'totalRevenue': 28262899712,
#  'debtToEquity': 27.41,
#  'revenuePerShare': 1.293498,
#  'returnOnAssets': 0.12737,
#  'returnOnEquity': 0.47427,
#  'grossProfits': 14492000256,
#  'freeCashflow': 6712999936,
#  'operatingCashflow': 11166199808,
#  'earningsGrowth': 0.318,
#  'revenueGrowth': 0.28,
#  'grossMargins': 0.51276,
#  'ebitdaMargins': 0.34892,
#  'operatingMargins': 0.36224,
#  'financialCurrency': 'EUR',
#  'symbol': 'ASML',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'regularMarketChange': -42.76996,
#  'regularMarketDayRange': '681.88 - 699.0',
#  'fullExchangeName': 'NasdaqGS',
#  'epsTrailingTwelveMonths': 20.72,
#  'epsForward': 26.7,
#  'epsCurrentYear': 23.92795,
#  'earningsTimestamp': 1744779600,
#  'earningsTimestampStart': 1744779600,
#  'earningsTimestampEnd': 1744779600,
#  'earningsCallTimestampStart': 1738159200,
#  'earningsCallTimestampEnd': 1738159200,
#  'isEarningsDateEstimate': False,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 795277800000,
#  'averageDailyVolume3Month': 1686401,
#  'fiftyTwoWeekLowChange': 44.0,
#  'fiftyTwoWeekLowChangePercent': 0.06816949,
#  'fiftyTwoWeekRange': '645.45 - 1110.09',
#  'fiftyTwoWeekHighChange': -420.63995,
#  'fiftyTwoWeekHighChangePercent': -0.3789242,
#  'fiftyTwoWeekChangePercent': -23.938625,
#  'dividendDate': 1746489600,
#  'averageAnalystRating': '1.8 - Buy',
#  'priceEpsCurrentYear': 28.813585,
#  'fiftyDayAverageChange': -42.315613,
#  'cryptoTradeable': False,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_388904',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'shortName': 'ASML Holding N.V. - New York Re',
#  'longName': 'ASML Holding N.V.',
#  'marketState': 'REGULAR',
#  'regularMarketChangePercent': -5.8411355,
#  'regularMarketPrice': 689.45,
#  'corporateActions': [],
#  'regularMarketTime': 1741625774,
#  'fiftyDayAverageChangePercent': -0.057826728,
#  'twoHundredDayAverageChange': -128.6352,
#  'twoHundredDayAverageChangePercent': -0.15723936,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'displayName': 'ASML Holding',
#  'trailingPegRatio': 1.4658}

# %%
tsmc.info
# Out:
# {'address1': 'Hsinchu Science Park',
#  'address2': 'No. 8, Li-Hsin Road 6',
#  'city': 'Hsinchu City',
#  'zip': '300096',
#  'country': 'Taiwan',
#  'phone': '886 3 563 6688',
#  'fax': '886 3 563 7000',
#  'website': 'https://www.tsmc.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Taiwan Semiconductor Manufacturing Company Limited, together with its subsidiaries, manufactures, packages, tests, and sells integrated circuits and other semiconductor devices in Taiwan, China, Europe, the Middle East, Africa, Japan, the United States, and internationally. It provides various wafer fabrication processes, such as processes to manufacture complementary metal- oxide-semiconductor (CMOS) logic, mixed-signal, radio frequency, embedded memory, bipolar CMOS mixed-signal, and others. The company also offers customer and engineering support services; manufactures masks; and invests in technology start-up companies; researches, designs, develops, manufactures, packages, tests, and sells color filters; and provides investment services. Its products are used in high performance computing, smartphones, Internet of things, automotive, and digital consumer electronics. The company was incorporated in 1987 and is headquartered in Hsinchu City, Taiwan.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Dr. C. C.  Wei Ph.D.',
#    'title': 'Chairman & CEO',
#    'fiscalYear': 2023,
#    'totalPay': 459800000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jen-Chau  Huang',
#    'title': 'Senior VP of Finance & CFO',
#    'fiscalYear': 2023,
#    'totalPay': 88200000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Y. P. Chyn',
#    'title': 'Executive VP of Operations & Overseas Operations Office and Co-COO',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Y. J. Mii',
#    'title': 'Executive VP of Research & Development and Co-COO',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Horng-Dar  Lin',
#    'title': 'Vice President of Corporate Information Technology & Chief Information Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeff  Su',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Sylvia  Fang',
#    'title': 'Senior VP of Legal, General Counsel & Corporate Governance Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Elizabeth  Sun',
#    'title': 'Senior Director of Corporate Communication Division',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Li Mei  He Ho',
#    'title': 'Senior Vice President of Human Resources',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Wei-Jen  Lo',
#    'title': 'Senior Vice President of Corporate Strategy Development',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 2,
#  'boardRisk': 2,
#  'compensationRisk': 1,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1740787200,
#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://www.tsmc.com/english/investorRelations/index.htm',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 1005.0,
#  'open': 1005.0,
#  'dayLow': 992.0,
#  'dayHigh': 1005.0,
#  'regularMarketPreviousClose': 1005.0,
#  'regularMarketOpen': 1005.0,
#  'regularMarketDayLow': 992.0,
#  'regularMarketDayHigh': 1005.0,
#  'dividendRate': 18.0,
#  'dividendYield': 1.79,
#  'exDividendDate': 1742256000,
#  'payoutRatio': 0.33150002,
#  'fiveYearAvgDividendYield': 2.05,
#  'beta': 1.255,
#  'trailingPE': 22.065,
#  'forwardPE': 17.287373,
#  'volume': 50901720,
#  'regularMarketVolume': 50901720,
#  'averageVolume': 37826608,
#  'averageVolume10days': 47358675,
#  'averageDailyVolume10Day': 47358675,
#  'bid': 1020.0,
#  'ask': 1025.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 25880833294336,
#  'fiftyTwoWeekLow': 740.0,
#  'fiftyTwoWeekHigh': 1160.0,
#  'priceToSalesTrailing12Months': 8.941977,
#  'fiftyDayAverage': 1089.6,
#  'twoHundredDayAverage': 1011.875,
#  'trailingAnnualDividendRate': 17.0,
#  'trailingAnnualDividendYield': 0.016915424,
#  'currency': 'TWD',
#  'tradeable': False,
#  'enterpriseValue': 24725499674624,
#  'profitMargins': 0.40537,
#  'floatShares': 23359946559,
#  'sharesOutstanding': 25932699648,
#  'heldPercentInsiders': 0.0,
#  'heldPercentInstitutions': 0.43182,
#  'impliedSharesOutstanding': 26666700800,
#  'bookValue': 165.372,
#  'priceToBook': 6.034879,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1735603200,
#  'earningsQuarterlyGrowth': 0.57,
#  'netIncomeToCommon': 1173267677184,
#  'trailingEps': 45.23,
#  'forwardEps': 57.73,
#  'lastSplitFactor': '1.005:1',
#  'lastSplitDate': 1247616000,
#  'enterpriseToRevenue': 8.543,
#  'enterpriseToEbitda': 12.508,
#  '52WeekChange': 0.3120104,
#  'SandP52WeekChange': 0.12744582,
#  'lastDividendValue': 4.5,
#  'lastDividendDate': 1749686400,
#  'quoteType': 'EQUITY',
#  'currentPrice': 998.0,
#  'targetHighPrice': 1800.0,
#  'targetLowPrice': 1250.0,
#  'targetMeanPrice': 1439.4366,
#  'targetMedianPrice': 1415.55,
#  'recommendationMean': 1.3125,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 30,
#  'totalCash': 2422019719168,
#  'totalCashPerShare': 93.396,
#  'ebitda': 1976850448384,
#  'totalDebt': 1050091126784,
#  'quickRatio': 2.131,
#  'currentRatio': 2.442,
#  'totalRevenue': 2894307786752,
#  'debtToEquity': 24.288,
#  'revenuePerShare': 111.631,
#  'returnOnAssets': 0.1353,
#  'returnOnEquity': 0.30036,
#  'grossProfits': 1624353538048,
#  'freeCashflow': 687589228544,
#  'operatingCashflow': 1826177024000,
#  'earningsGrowth': 0.57,
#  'revenueGrowth': 0.388,
#  'grossMargins': 0.56122,
#  'ebitdaMargins': 0.68301004,
#  'operatingMargins': 0.49019,
#  'financialCurrency': 'TWD',
#  'symbol': '2330.TW',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'corporateActions': [{'header': 'Dividend',
#    'message': '2330.TW announced a cash dividend of 4.50 with an ex-date of Mar. 18, 2025',
#    'meta': {'eventType': 'DIVIDEND',
#     'dateEpochMs': 1742227200000,
#     'amount': '4.50'}}],
#  'regularMarketTime': 1741584602,
#  'exchange': 'TAI',
#  'messageBoardId': 'finmb_380075',
#  'exchangeTimezoneName': 'Asia/Taipei',
#  'exchangeTimezoneShortName': 'CST',
#  'gmtOffSetMilliseconds': 28800000,
#  'market': 'tw_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': -0.6965174,
#  'regularMarketPrice': 998.0,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 946947600000,
#  'marketState': 'PREPRE',
#  'fiftyDayAverageChange': -91.599976,
#  'fiftyDayAverageChangePercent': -0.08406752,
#  'twoHundredDayAverageChange': -13.875,
#  'twoHundredDayAverageChangePercent': -0.013712168,
#  'sourceInterval': 20,
#  'exchangeDataDelayedBy': 20,
#  'averageAnalystRating': '1.3 - Strong Buy',
#  'cryptoTradeable': False,
#  'shortName': 'TAIWAN SEMICONDUCTOR MANUFACTUR',
#  'longName': 'Taiwan Semiconductor Manufacturing Company Limited',
#  'regularMarketChange': -7.0,
#  'regularMarketDayRange': '992.0 - 1005.0',
#  'fullExchangeName': 'Taiwan',
#  'averageDailyVolume3Month': 37826608,
#  'fiftyTwoWeekLowChange': 258.0,
#  'fiftyTwoWeekLowChangePercent': 0.34864864,
#  'fiftyTwoWeekRange': '740.0 - 1160.0',
#  'fiftyTwoWeekHighChange': -162.0,
#  'fiftyTwoWeekHighChangePercent': -0.13965517,
#  'fiftyTwoWeekChangePercent': 31.20104,
#  'earningsTimestamp': 1737025140,
#  'earningsTimestampStart': 1744801140,
#  'earningsTimestampEnd': 1745236800,
#  'earningsCallTimestampStart': 1737007200,
#  'earningsCallTimestampEnd': 1737007200,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 45.23,
#  'epsForward': 57.73,
#  'epsCurrentYear': 60.15024,
#  'priceEpsCurrentYear': 16.591787,
#  'trailingPegRatio': 1.0336}

# %%
apple_hist=apple.history(period="10y")
asml_hist=asml.history(period="10y")
tsmc_hist=tsmc.history(period="10y")

# %%
apple_holder=apple.major_holders
novo_holder=novo.major_holders
tsmc_holder=tsmc.major_holders

# %%
apple_holder
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.02268
# institutionsPercentHeld          0.62777
# institutionsFloatPercentHeld     0.64234
# institutionsCount             6986.00000

# %%
apple_institutional_holders=apple.institutional_holders
asml_institutional_holders=asml.institutional_holders
tsmc_institutional_holders=tsmc.institutional_holders

# %%
asml_institutional_holders
# Out:
#   Date Reported                                     Holder  pctHeld   Shares  \
# 0    2024-12-31                    Capital World Investors   0.0117  4599999
# 1    2024-12-31            Capital International Investors   0.0087  3432077
# 2    2024-12-31                                   FMR, LLC   0.0085  3354140
# 3    2024-12-31                    Edgewood Management Llc   0.0081  3186667
# 4    2024-12-31               Fisher Asset Management, LLC   0.0080  3162286
# 5    2024-12-31              Price (T.Rowe) Associates Inc   0.0074  2918871
# 6    2024-12-31  State Farm Mutual Automobile Insurance Co   0.0070  2758173
# 7    2024-12-31                             Morgan Stanley   0.0068  2677445
# 8    2024-12-31                  JP Morgan Chase & Company   0.0066  2588600
# 9    2024-12-31             Van Eck Associates Corporation   0.0045  1788280
#
#         Value  pctChange
# 0  3162959200    -0.2206
# 1  2359896061    -0.0504
# 2  2306306582    -0.1565
# 3  2191152151     0.4309
# 4  2174387776    -0.0075
# 5  2007015628    -0.1740
# 6  1896519687     0.0000
# 7  1841011116     0.4673
# 8  1779921296     0.8203
# 9  1229621284     0.0178

# %%
aplle_recco=apple.recommendations
novo_recco=novo.recommendations
tsmc_recco=tsmc.recommendations

# %%
aplle_recco
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          7   21    13     2           2
# 1    -1m          7   21    13     2           2
# 2    -2m          8   21    13     2           2
# 3    -3m          8   24    12     1           2

# %%
apple_hist.plot(kind="line", figsize=(12,12),subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
asml_hist.plot(kind="line", figsize=(12,12),subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
tsmc_hist.plot(kind="line", figsize=(12,12),subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
from scipy.optimize import minimize

#Définition des actifs et du taux sans risque (3%)
assets = ["AAPL", "ASML", "2330.TW"]  # Apple, ASML, TSMC
risk_free_rate = 0.03  # 3% en notation décimale

#Télécharger les données de prix ajustés sur 5 ans
data = yf.download(assets, start="2019-01-01", end="2024-01-01")["Close"]

#Calcul des rendements journaliers
returns = data.pct_change().dropna()

#Calcul des rendements et volatilités annuels
mean_returns = returns.mean() * 252  # Annualisation des rendements
cov_matrix = returns.cov() * 252  # Annualisation de la matrice de covariance

#Fonction du ratio de Sharpe (objectif à maximiser)
def sharpe_ratio(weights):
    portfolio_return = np.dot(weights, mean_returns)
    portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    return -(portfolio_return - risk_free_rate) / portfolio_volatility  # On minimise donc -Sharpe

#Contraintes : la somme des poids doit être égale à 1
constraints = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1})

#Bornes des poids entre 0% et 100%
bounds = tuple((0, 1) for asset in assets)

#Initialisation des poids égaux
init_guess = [1 / len(assets)] * len(assets)

#Optimisation du ratio de Sharpe
optimal = minimize(sharpe_ratio, init_guess, method='SLSQP', bounds=bounds, constraints=constraints)

#Extraction des résultats
optimal_weights = optimal.x
optimal_return = np.dot(optimal_weights, mean_returns)
optimal_volatility = np.sqrt(np.dot(optimal_weights.T, np.dot(cov_matrix, optimal_weights)))
optimal_sharpe = (optimal_return - risk_free_rate) / optimal_volatility

#Affichage des résultats
print("📊 Pondérations optimales pour maximiser le ratio de Sharpe :")
for i, asset in enumerate(assets):
    print(f"  {asset}: {optimal_weights[i]:.2%}")

print(f"\n📈 Rentabilité annuelle du portefeuille optimal: {optimal_return:.2%}")
print(f"📉 Volatilité annuelle du portefeuille optimal: {optimal_volatility:.2%}")
print(f"⚡ Ratio de Sharpe optimal: {optimal_sharpe:.2f}")
# Out:
# [*********************100%***********************]  3 of 3 completed
# 📊 Pondérations optimales pour maximiser le ratio de Sharpe :
#   AAPL: 47.14%
#   ASML: 39.94%
#   2330.TW: 12.92%
#
# 📈 Rentabilité annuelle du portefeuille optimal: 31.64%
# 📉 Volatilité annuelle du portefeuille optimal: 21.45%
# ⚡ Ratio de Sharpe optimal: 1.34
# <ipython-input-45-54f6dea9b495>:14: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = data.pct_change().dropna()
